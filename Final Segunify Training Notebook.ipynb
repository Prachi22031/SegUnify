# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input/segunify-optimized-eval-224-4-img'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/smooseg-optimized-eval-224-4-img/data.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/LICENSE
# /kaggle/input/smooseg-optimized-eval-224-4-img/vits.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/train_segmentation.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/README.md
# /kaggle/input/smooseg-optimized-eval-224-4-img/crf.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/crop_datasets.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/utils.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/requirements.txt
# /kaggle/input/smooseg-optimized-eval-224-4-img/modules.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/download_datasets.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/__init__.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/eval_segmentation.py
# /kaggle/input/smooseg-optimized-eval-224-4-img/assets/framework.jpg
# /kaggle/input/smooseg-optimized-eval-224-4-img/configs/train_config.yaml
# ...

# %%
import os

output_dir = '/kaggle/working/output/'

os.makedirs(output_dir, exist_ok=True)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.4.0
# True

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==1.12.1+cu116 torchvision==0.13.1+cu116 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 GB 466.2 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 73.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 88.9 MB/s eta 0:00:00:00:01
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install -r /kaggle/input/segunify-optimized-eval-224-4-img/requirements.txt
# Out:
# ...
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-cz26x1ox
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-cz26x1ox
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !python /kaggle/input/segunify-optimized-eval-224-4-img/crop_datasets.py
# Out:
# /kaggle/input/smooseg-optimized-eval-224-4-img/crop_datasets.py:284: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="train_config.yaml")
# /opt/conda/lib/python3.10/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# output_root: /kaggle/working/output/
# data_dir: /kaggle/input/
# experiment_name: exp1
# log_dir: logs
# checkpoint_dir: checkpts
# azureml_logging: true
# num_workers: 4
# max_steps: 3000
# batch_size: 32
# dataset_name: potsdam
# crop_type: five
# crop_ratio: 0.5
# res: 224
# loader_crop_type: center
# extra_clusters: 0
# model_type: vit_base
# arch: dino
# dino_feat_type: feat
# ...

# %%
# !pip cache purge
# Out:
# Files removed: 385

# %%
# !pip install --force-reinstall --no-deps cryptography==42.0.8 --ignore-installed
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 44.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !python /kaggle/input/segunify-optimized-eval-224-4-img/train_segmentation.py
# Out:
# /opt/conda/lib/python3.10/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# output_root: /kaggle/working/output/
# data_dir: /kaggle/input/
# experiment_name: exp1
# log_dir: logs
# checkpoint_dir: checkpts
# azureml_logging: true
# num_workers: 4
# max_steps: 3000
# batch_size: 32
# dataset_name: potsdam
# crop_type: five
# crop_ratio: 0.5
# res: 224
# loader_crop_type: center
# extra_clusters: 0
# model_type: vit_base
# arch: dino
# dino_feat_type: feat
# projection_type: nonlinear
# dino_patch_size: 8
# n_feats: 768
# dim: 64
# run_crf: false
# lr1: 0.0001
# lr2: 0.0005
# dropout: true
# temperature: 0.1
# alpha: 0.998
# pointwise: true
# seed: 0
# neg_inter_shift: 0.5
# pos_intra_shift: 0.1
# n_images: 6
# scalar_log_freq: 10
# checkpoint_freq: 400
# val_freq: 400
# ...

# %%
import shutil
shutil.make_archive('output', 'zip', 'output')  # Folder 'outputs' will be saved as 'outputs.zip'
shutil.move("output.zip", "/kaggle/working/output.zip")
# Out:
# '/kaggle/working/output.zip'

# %%
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:128'

# %%
# !python /kaggle/input/segunify-optimized-eval-224-4-img/eval_segmentation.py
# Out:
# /opt/conda/lib/python3.10/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Created results directory at: /kaggle/working/results
# Loading model from checkpoint: /kaggle/working/output/checkpoints/potsdam_exp1.ckpt
# Since no pretrained weights have been provided, we load the reference pretrained DINO weights.
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 54/54 [02:45<00:00,  3.06s/it]
# Found 855 total results, saving top 10...
# Saving image top_1_iou_1.000 to directories:
# Saving image top_2_iou_1.000 to directories:
# ...

# %%
import shutil
shutil.make_archive('results', 'zip', 'results')
shutil.move("results.zip", "/kaggle/working/results.zip")
# Out:
# '/kaggle/working/results.zip'
